# %% [markdown]
# # Retrieve data

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('Spotify_Youtube.csv')

# %%
droppedcolumns = ["Url_spotify","Uri","Url_youtube","Description"] # Data irrelevant to the content of the song
for x in droppedcolumns:
    df = df.drop(labels = x , axis=1)

# %%
# Removing rows with missing values
df = df.dropna()

# Removing songs that exceed 10 minutes, getting rid of compilations and ASMR
df = df.drop(df[df.Duration_ms > 600000].index)

# %%
# Semi-Manual Check for audiobooks and other non-songs

songs_removed1 = []
number1 = []

blacklist = ["Folge","Teil","Meditation","Hz","These Words"] 


for x in range(0,len(df.index)):
    for y in blacklist:
        if y in df.iloc[x]['Album'] or y in df.iloc[x]['Track'] or y in df.iloc[x]['Title']:
            songs_removed1.append(str(df.iloc[x][2]))
            number1.append(x)

bchannels = ["Rain Fruits Sounds", "Ocean Sounds","Ocean Waves For Sleep","White Noise for Babies", "White Noise Baby Sleep", "Sleepy Penguin"]

for x in range(0,len(df.index)):
    for y in bchannels:
        if y in df.iloc[x]["Artist"]:
            songs_removed1.append(str(df.iloc[x][2]))
            number1.append(x)


number1 = list(dict.fromkeys(number1))
number1.sort()

# Drop here
number = df.index[number1]
df = df.drop(number)

# Final csv
df.to_csv("data_clean.csv")

#print total null rows
print(df.isnull().sum())
# Out:
# Unnamed: 0          0
# Artist              0
# Track               0
# Album               0
# Album_type          0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Duration_ms         0
# Title               0
# Channel             0
# Views               0
# Likes               0
# Comments            0
# Licensed            0
# official_video      0
# Stream              0
# dtype: int64
# C:\Users\Xinyang\AppData\Local\Temp\ipykernel_12880\671036860.py:37: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   rule = ((df < (Q1 - 1.5 * (Q3 - Q1))) | (df > (Q3 + 1.5 *(Q3 -Q1))))
# ...

# %%
df.head()
# Out:
#    Unnamed: 0    Artist                                          Track  \
# 0           0  Gorillaz                                 Feel Good Inc.
# 1           1  Gorillaz                                Rhinestone Eyes
# 2           2  Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3           3  Gorillaz                             On Melancholy Hill
# 4           4  Gorillaz                                 Clint Eastwood
#
#                                            Album Album_type  Danceability  \
# 0                                     Demon Days      album         0.818
# 1                                  Plastic Beach      album         0.676
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single         0.695
# 3                                  Plastic Beach      album         0.689
# 4                                       Gorillaz      album         0.663
#
#    Energy   Key  Loudness  Speechiness  ...    Tempo  Duration_ms  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19343 entries, 0 to 20717
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        19343 non-null  int64
#  1   Artist            19343 non-null  object
#  2   Track             19343 non-null  object
#  3   Album             19343 non-null  object
#  4   Album_type        19343 non-null  object
#  5   Danceability      19343 non-null  float64
#  6   Energy            19343 non-null  float64
#  7   Key               19343 non-null  float64
#  8   Loudness          19343 non-null  float64
#  9   Speechiness       19343 non-null  float64
#  10  Acousticness      19343 non-null  float64
#  11  Instrumentalness  19343 non-null  float64
#  12  Liveness          19343 non-null  float64
#  13  Valence           19343 non-null  float64
#  14  Tempo             19343 non-null  float64
#  15  Duration_ms       19343 non-null  float64
# ...

# %%
print(df.dtypes)
# Out:
# Unnamed: 0            int64
# Artist               object
# Url_spotify          object
# Track                object
# Album                object
# Album_type           object
# Uri                  object
# Danceability        float64
# Energy              float64
# Key                 float64
# Loudness            float64
# Speechiness         float64
# Acousticness        float64
# Instrumentalness    float64
# Liveness            float64
# Valence             float64
# Tempo               float64
# Duration_ms         float64
# Url_youtube          object
# Title                object
# Channel              object
# Views               float64
# Likes               float64
# Comments            float64
# Description          object
# Licensed             object
# official_video       object
# Stream              float64
# dtype: object

# %% [markdown]
# ### data cleaned
